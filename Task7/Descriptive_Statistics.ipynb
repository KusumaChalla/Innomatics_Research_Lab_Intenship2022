# %% [markdown]
# # Descriptive Statistics
#
# **1.Mean  <!--spaces-->
# 2.Median
# 3.Mode
# 4.Variance
# 5.Standard Deviation
# 6.Correlation
# 7.Normal Distribution (use references)
# 8.Feature of Normal Distribution
# 9.Positively Skewed & Negatively Skewed Normal Distribution
# 10.Effect on Mean, Median and Mode due to Skewness
# 11.Explain QQ Plot and show the implementation of the same
# 12.Explain Box Cox and show the implementation of the same**

# %% [markdown]
# __Importing Libraries__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# __reading data.csv file__

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# __Info about dataframe__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Descriptive Statistics
# ---
# Descriptive statistics deals with the formulation of simple summaries of data so that they can be clearly understood. The summaries of data may be either numerical representations or visualizations with simple graphs are used.
#
# There are two types of descriptive statistics:
# 1.Measures of central tendency
# 2.Measures of variability (spread)
#
# Measures of central tendency include mean, median, and mode, while measures of variability include standard deviation (or variance), the minimum and maximum values of the variables, kurtosis, and skewness.

# %% [markdown]
# __Mean__
#
# The mean or average is a number around which the observed continuous variables are distributed. This number estimates the value of the entire dataset.
#
#    Mathematically, it is the result of the division of the sum of numbers by the number of integers in the dataset.

# %%
df.mean()
# Out:
# Mthly_HH_Income           41558.00
# Mthly_HH_Expense          18818.00
# No_of_Fly_Members             4.06
# Emi_or_Rent_Amt            3060.00
# Annual_HH_Income         490019.04
# No_of_Earning_Members         1.46
# dtype: float64

# %% [markdown]
# __Median__
#
# Dataset that is sorted either in ascending or descending order, the median divides the data into two parts

# %%
df.median()
# Out:
# Mthly_HH_Income           35000.0
# Mthly_HH_Expense          15500.0
# No_of_Fly_Members             4.0
# Emi_or_Rent_Amt               0.0
# Annual_HH_Income         447420.0
# No_of_Earning_Members         1.0
# dtype: float64

# %% [markdown]
# __Mode__
#
# The mode is the integer that appears the maximum number of times in the dataset. It happens to be the value with the highest frequency in the dataset

# %%
df.mode()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0            45000             25000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0            590400                 Graduate                      1

# %% [markdown]
# __find descriptive statistics for the entire dataset at once__

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %% [markdown]
# __Variance__
#
# Variance is the square of the average/mean of the difference between each value in the dataset with its average/mean that is, it is the square of standard deviation

# %%
variance=df.var()
print(variance)
# Out:
# Mthly_HH_Income          6.811009e+08
# Mthly_HH_Expense         1.461733e+08
# No_of_Fly_Members        2.302449e+00
# Emi_or_Rent_Amt          3.895551e+07
# Annual_HH_Income         1.024869e+11
# No_of_Earning_Members    5.391837e-01
# dtype: float64

# %% [markdown]
# __Standard deviation__
#
# The standard deviation is the average/mean of the difference between each value in the dataset with its average/mean; that is, how data is spread out from the mean. If the standard deviation of the dataset is low, then the data points tend to be close to the mean of the dataset, otherwise, the data points are spread out over a wider range of values.

# %%
std_dev =df.std()
print(std_dev)
# Out:
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64

# %% [markdown]
# __Correlation__
#
# Any dataset that we want to analyze will have different fieldsn(that is,columns
# of multiple observations (that is, variables)representing different facts.
#
# The columns of a dataset are, most probably,related to one another because they
# are collected from the same event.One field of record may or may not affect
# the value of another field.
#
# To examine the type of relationships these columns have and to analyze
# the causes and effects between them, we have to work to find the dependencies
# that exist among variables.
#
# The strength of such a relationship between two fields of a dataset is called
# correlation, which is represented by a numerical value between -1 and 1.

# %% [markdown]
# __Definition For Correlation__
#
# The statistical technique that examines the relationship and explains whether, and how strongly, pairs of variables are related to one another is known as correlation.
#
# Correlation answers questions such as how one variable changes with respect to another. If it does change, then to what degree or strength? Additionally, if the relation between those variables is strong enough, then we can make predictions for future behavior.

# %%
df.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %% [markdown]
# If the correlation is +1, then it is said to be a perfect positive/linear correlation (that is, variable A is directly proportional to variable B)
#
# while a correlation of -1 is a perfect negative correlation (that is, variable A is inversely proportional to variable B).Values closer to 0 are not supposed to be correlated at all.
#
# If correlation coefficients are near to 1 in absolute value, then the variables are said to be strongly correlated; in comparison, those that are closer to 0.5 are said to be weakly correlated.

# %%
dataplot = sns.heatmap(df.corr(), cmap="icefire", annot=True)
plt.show()

# %% [markdown]
# _In the dataset given variables Mthly_HH_Income, Mthly_HH_Expense are moderately positively correlated and Mthly_HH_Expense, Mthly_HH_Income are moderately positively correlated with 0.65,0.64 correlation values_.

# %% [markdown]
# __Normal Distribution__
#
# Normal distribution/Gaussian distribution is a function that distributes the list of random variables in a graph that is shaped like a symmetrical bell.
#
# A normal distribution has a density curve that is symmetrical about its mean, with its spread typically defined by its standard deviation. It has two parameters – the mean and the standard deviation.
#
# If the size of all possible samples in a population is n, and the mean is μ and the variance σ2 , then the distribution approaches a normal distribution.

# %% [markdown]
# __In a standard normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3.__

# %% [markdown]
# __Many methods exit for testing whether a variable has a normal distribution__
#
# __some of them are histogram:
# The histogram is a data visulaization that shows the distribution of a variable.
# It gives us the frequeny of occurence per value in the dataset__
#
# __boxplot:
# The boxplot is anotherr visualizatio technique that can be used for detecting non-normal samples.The Boxplot plots the 5-number summary of a variable minimum,first quartile,median,third quartile and maximum__.
#
# __In a box plot a deviation in width/pointiness is hard to identify using box plot__
#
# __and QQplot__

# %%
#taking out the object type column
df1 =df.drop(['Highest_Qualified_Member'], axis=1)

# %%
#histogram for the variables
k = len(df1.columns)
n = 2
m = (k - 1) // n + 1
fig, axes = plt.subplots(m, n, figsize=(n * 5, m * 3))
for i, (name, col) in enumerate(df1.iteritems()):
    r, c = i // n, i % n
    ax = axes[r, c]
    col.hist(ax=ax)
    ax2 = col.plot.kde(ax=ax, secondary_y=True, title=name,label="normal distr")
    ax2.set_ylim(0)
    ax2.legend()

fig.tight_layout()

# %% [markdown]
# _all the variables are not in normal distribution and varaibles like Mthly_HH_Income,Mthly_HH_Expense,Emi_or_Rent_Amt,Annual_HH_Income,No_of_EarningMembers are right skewed_

# %% [markdown]
# __Feature of Normal Distribution__:
#
# 1.The Data Is Centered About the Mean-Mode-Median
#
# 2.The probability a score is above the mean is 50% and the probability a score is below the mean is 50%.
#
# 3.Most of the scores are in the middle, about the mean, and few are in the tails, at the extremes.
#
# 4.The area under the curve is equal to 1.
#
# 5.The probability of an event that does not happen is 0.
#
# 6.The sum of the probabilities of all events is 1.
#
# 7.The standard deviation tells one how the scores are spread out and therefore the fatness or skinniness of the bell.
#
# 8.Since normally distributed data is spread in terms of the mean and standard deviation, the percent of scores, within the same region, remains the same from normal distribution to normal distribution.

# %% [markdown]
# __Positively Skewed & Negatively Skewed Normal Distribution__
#
# __Skewness__:
#
# Skewness is a measure of the asymmetry of the variable in the dataset about its mean.
# The skewness value can be positive or negative, or undefined. The skewness value tells us whether the data is skewed or symmetric.
#
# __Negative Skewness__:
#
# If in a graph the tail  is longer on the light-hand side.This indicates that the distribution of the data is skewed to the left.
#
# If you select any point in the left-hand longer tail, the mean is less than the mode. This condition is referred to as negative skewness.
#
# __Positive Skewness__:
#
# If in a graph the tail  is longer on the right-hand side.This indicates that the distribution of the data is skewed to the right.
#
# If you select any point on the right-hand tail, the mean value is greater than the mode. This condition is referred to as positive skewness.
#
# __If in a graph the right-hand tail is the same as the left-hand tail. This condition is referred to as a symmetrical condition__.

# %%
axis = sns.distplot(df['No_of_Fly_Members'], bins=5, kde=True, color='blue', hist_kws={"linewidth": 15,'alpha':0.1})
axis.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# _variable No_of_Fly_Members doesn't follows normal distribution_

# %%
axis = sns.distplot(df['No_of_Earning_Members'], bins=5, kde=True, color='blue', hist_kws={"linewidth": 15,'alpha':0.1})
axis.set(xlabel='No_of_Earning_Members', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'No_of_Earning_Members'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# _variable No_of_Earning_Members doesn't follows normal distribution and has right skewness_

# %% [markdown]
# __Effect on Mean, Median and Mode due to Skewness__
#
# The mean is affected by outliers that do not influence the mean. Therefore, when the distribution of data is skewed to the left, the mean is often less than the median.
#
# When the distribution is skewed to the right, the mean is often greater than the median and mode is smallest.
#
# The greater the deviation from zero indicates a greater degree of skewness.If the skewness is negative then the distribution is skewed left and mode is the largest
#
# A positive measure of skewness indicates right skewness
#
# The skewness for a normal distribution is zero.
#
# The skewness characterizes the degree of asymmetry of a distribution around its mean.

# %%
a = df1.columns
list1 = list(a)

for i in list1:
    mean = float(df1[i].mean())
    median = float(df1[i].median())
    mode = float(df1[i].mode())
    skew_  = float(df1[i].skew())
    if mean<median and median<mode:
        print(i,"skewed to the left")
    elif mode<median and median<mean:
        print(i,"skewed to the right")
    elif (mean==median and median==mode):
        print(i,"symmetrical data")
    else:
        print("skewness value {} of {} ".format(skew_,i))
# Out:
# skewness value 0.9246148763777229 of Mthly_HH_Income
# skewness value 1.1994608030097127 of Mthly_HH_Expense
# skewness value 0.11367415455857431 of No_of_Fly_Members
# skewness value 3.403679844103547 of Emi_or_Rent_Amt
# skewness value 1.1929490975818218 of Annual_HH_Income
# skewness value 1.5933009869600223 of No_of_Earning_Members

# %% [markdown]
# __QQplot__:
#
# QQ plot stands for Quantile vs Quantile Plot,which is exactly plotting theoretical quantiles against the actua quantiles of the varaible.
#
# QQplot allows us to see deviation of a normal distribution much better than in a Histogram or Box Plot
#
# If our variable follows a normal distribution the quantiles of our variablemust be perfectly in line with the "theroretical  normal quantiles:a straight line on the QQplot tells we have a normal distribution.
#
# The uniform distribution has too many observations in bothextremities(very hight and low values)
#
# The exponential distribution has too many obserations on the lower values but too little in the higher values

# %%
import statsmodels.api as sm
import pylab as py
a = df1.columns
list1 = list(a)

for i in list1:
    sm.qqplot(df1[i],line="45",fit=True)
    py.title(i)
    py.show()

# %% [markdown]
# _varaibles Mthly_HH_Income,Annual_HH_Income,Mthly_HH_Expense are slightly uniformaly distributed_

# %% [markdown]
# __Box Cox__:
#
# The Box-Cox tranformation tranforms our data so that is closely resembles a normal distribution.
#
# Transforming our varaibles can improve the predictive power of oue models because tranformations can cut away from all variables having the same variance (sigma^2) and each value having a zero correlation with all other values.
#
# At the core of the Box Cox transformation is an exponent, lambda (λ), which varies from -5 to 5. All values of λ are considered and the optimal value for your data is selected; The “optimal value” is the one which results in the best approximation of a normal distribution curve. The transformation of Y has the form:
#
# $$
#     y(\lambda) = \left \{
#             \begin{array}\\
#                 log y & \mbox{if } \ \lambda = 0 \\
#                 \frac{y^\lambda -1,}{\lambda} & \mbox{if }\ \lambda\neq0 \\
#             \end{array}
#     \right.
# $$

# %%
# varaible Mthly_HH_Income box-cox transformation
from scipy import stats
tdata,lambd = stats.boxcox(df['Mthly_HH_Income'])

fig, ax = plt.subplots(1,2)

sns.distplot(tdata,label="Normal",color="green",ax=ax[1])

sns.distplot(df['Mthly_HH_Income'],label ='Not normal',color="orange",ax=ax[0])

plt.legend()
fig.set_figheight(5)
fig.set_figwidth(10)
print(f"Lambda value used for Transformation: {lambd}")
# Out:
# Lambda value used for Transformation: 0.3031376789702236

# %%
# varaible Mthly_HH_Expense box-cox transformation
from scipy import stats
tdata,lambd = stats.boxcox(df['Mthly_HH_Expense'])

fig, ax = plt.subplots(1,2)

sns.distplot(tdata,label="Normal",color="green",ax=ax[1])

sns.distplot(df['Mthly_HH_Expense'],label ='Not normal',color="orange",ax=ax[0])

plt.legend()
fig.set_figheight(5)
fig.set_figwidth(10)
print(f"Lambda value used for Transformation: {lambd}")
# Out:
# Lambda value used for Transformation: 0.18883043817938627

# %%
# varaible Annual_HH_Income box-cox transformation
from scipy import stats
tdata,lambd = stats.boxcox(df['Annual_HH_Income'])

fig, ax = plt.subplots(1,2)

sns.distplot(tdata,label="Normal",color="green",ax=ax[1])

sns.distplot(df['Annual_HH_Income'],label ='Not normal',color="orange",ax=ax[0])

plt.legend()
fig.set_figheight(5)
fig.set_figwidth(10)
print(f"Lambda value used for Transformation: {lambd}")
# Out:
# Lambda value used for Transformation: 0.24689401204475175
